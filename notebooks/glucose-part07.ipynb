# %% [markdown]
# Converting code into modules/functions to save time - woo!

# %%
# since this notebook lives in a sub-folder of the main project, I'll add the main folder to the python path
import sys
sys.path.append("../")

from tools.sugar_plots import daily_tir

# %%
# Plot daily TIR
data_folder = r"../data/glooko/"
fig, ax = daily_tir(data_folder, min_target=70, max_target=180)
