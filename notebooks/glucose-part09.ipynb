# %% [markdown]
# Today I think I'll play around with splitting days into segments - breakfast, lunch, dinner, etc. And then use that to look at carb ratios.

# %%
# since this notebook lives in a sub-folder of the main project, I'll add the main folder to the python path
import sys
sys.path.append("../")
import tools.glooko as gl
import tools.sugar_plots as spl

# plotting etc
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib widget

import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## Import the data

# %%
data_folder = r"../data"
df_cgm, df_bolus, df_basal, df_insulin, df_cgm_daily = gl.merge_data(data_folder)
df_cgm.sort_values(by="time", inplace=True)


df_cgm["hour"] = df_cgm["time"].dt.hour

# %% [markdown]
# ## Quick plot
# Just a quick plot to test an update I made to some functions/modules.

# %%
data_folder = r"../data"
fig, ax = spl.daily_tir(data_folder, min_target=70, max_target=180)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Define the hour limits
#
# Determine times of interest (meals)
